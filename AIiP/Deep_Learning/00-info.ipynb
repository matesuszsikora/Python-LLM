# %%
import torch


def test_pytorch_setup():
    print("PyTorch Version:", torch.__version__)
    print("CUDA Available:", torch.cuda.is_available())

    if torch.cuda.is_available():
        print("GPU Device Name:", torch.cuda.get_device_name(0))
        print("Number of GPUs:", torch.cuda.device_count())

        # Test tensor operation on GPU
        x = torch.rand(3, 3).cuda()
        y = torch.rand(3, 3).cuda()
        z = x + y
        print("Test Tensor Operation on GPU:\n", z)
    else:
        print("Running on CPU. GPU not available.")


if __name__ == "__main__":
    test_pytorch_setup()
# Out:
# PyTorch Version: 2.9.0+cu126
# CUDA Available: True
# GPU Device Name: NVIDIA GeForce GTX 1070
# Number of GPUs: 1
# Test Tensor Operation on GPU:
#  tensor([[0.9694, 0.4366, 1.3950],
#         [0.7502, 1.2932, 1.2767],
#         [0.9614, 0.8994, 1.1348]], device='cuda:0')

# %%
# Udało sie uruchomić i sprawdzić GPU
